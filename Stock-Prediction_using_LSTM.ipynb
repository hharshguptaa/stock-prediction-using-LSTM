# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060524
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062686
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063767
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062145
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061065
# ...          ...         ...         ...         ...         ...         ...
# 9405  2023-07-10  334.600006  335.230011  327.589996  331.829987  331.829987
# 9406  2023-07-11  331.059998  332.859985  327.000000  332.470001  332.470001
# 9407  2023-07-12  336.600006  341.649994  335.670013  337.200012  337.200012
# 9408  2023-07-13  339.559998  343.739990  339.019989  342.660004  342.660004
# 9409  2023-07-14  347.589996  351.429993  344.309998  345.239990  345.239990
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9405    32791400
# 9406    26698200
# 9407    29995300
# 9408    20567200
# 9409    28302200
#
# [9410 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9405  2023-07-10  331.829987
# 9406  2023-07-11  332.470001
# 9407  2023-07-12  337.200012
# 9408  2023-07-13  342.660004
# 9409  2023-07-14  345.239990
#
# [9410 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9405    2023-07-10
# 9406    2023-07-11
# 9407    2023-07-12
# 9408    2023-07-13
# 9409    2023-07-14
# Name: Date, Length: 9410, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9405  2023-07-10  331.829987
# 9406  2023-07-11  332.470001
# 9407  2023-07-12  337.200012
# 9408  2023-07-13  342.660004
# 9409  2023-07-14  345.239990
#
# [9410 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\sunil\AppData\Local\Temp\ipykernel_27112\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9405   2023-07-10
# 9406   2023-07-11
# 9407   2023-07-12
# 9408   2023-07-13
# 9409   2023-07-14
# Name: Date, Length: 9410, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-07-10  331.829987
# 2023-07-11  332.470001
# 2023-07-12  337.200012
# 2023-07-13  342.660004
# 2023-07-14  345.239990
#
# [9410 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 84440.3984 - mean_absolute_error: 288.9836 - val_loss: 92535.5391 - val_mean_absolute_error: 304.1095
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 83953.2344 - mean_absolute_error: 288.0295 - val_loss: 92364.0625 - val_mean_absolute_error: 303.8274
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 85875.0469 - mean_absolute_error: 291.4181 - val_loss: 92155.5625 - val_mean_absolute_error: 303.4841
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 83287.8594 - mean_absolute_error: 286.8260 - val_loss: 91839.4297 - val_mean_absolute_error: 302.9628
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 84234.6719 - mean_absolute_error: 288.4446 - val_loss: 91370.0391 - val_mean_absolute_error: 302.1871
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 84450.9688 - mean_absolute_error: 288.7261 - val_loss: 90644.5391 - val_mean_absolute_error: 300.9843
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 82283.0781 - mean_absolute_error: 285.0491 - val_loss: 89770.8672 - val_mean_absolute_error: 299.5294
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 82569.7500 - mean_absolute_error: 285.4971 - val_loss: 88632.8594 - val_mean_absolute_error: 297.6236
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 80756.4688 - mean_absolute_error: 282.4912 - val_loss: 86840.3906 - val_mean_absolute_error: 294.5971
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 78523.0469 - mean_absolute_error: 278.4214 - val_loss: 85127.2734 - val_mean_absolute_error: 291.6749
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 77389.6094 - mean_absolute_error: 276.3021 - val_loss: 82866.2031 - val_mean_absolute_error: 287.7727
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 75369.8281 - mean_absolute_error: 272.7222 - val_loss: 80006.3984 - val_mean_absolute_error: 282.7602
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 71358.7734 - mean_absolute_error: 265.2883 - val_loss: 76319.8359 - val_mean_absolute_error: 276.1644
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 68429.0547 - mean_absolute_error: 259.7794 - val_loss: 72616.7188 - val_mean_absolute_error: 269.3766
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 63711.4258 - mean_absolute_error: 250.4524 - val_loss: 68741.8047 - val_mean_absolute_error: 262.0855
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 61798.4062 - mean_absolute_error: 246.4298 - val_loss: 64393.4688 - val_mean_absolute_error: 253.6543
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 58055.5078 - mean_absolute_error: 238.6812 - val_loss: 59784.8438 - val_mean_absolute_error: 244.4010
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 52188.3711 - mean_absolute_error: 226.2521 - val_loss: 54527.5117 - val_mean_absolute_error: 233.3978
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 45991.6953 - mean_absolute_error: 212.1517 - val_loss: 49103.5469 - val_mean_absolute_error: 221.4735
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 42506.8008 - mean_absolute_error: 203.7902 - val_loss: 43503.1758 - val_mean_absolute_error: 208.4471
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37676.1211 - mean_absolute_error: 191.4307 - val_loss: 38055.1836 - val_mean_absolute_error: 194.9416
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32907.1328 - mean_absolute_error: 178.4712 - val_loss: 32658.0449 - val_mean_absolute_error: 180.5688
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27790.0645 - mean_absolute_error: 163.4597 - val_loss: 27474.9121 - val_mean_absolute_error: 165.5956
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22142.5664 - mean_absolute_error: 145.2655 - val_loss: 22049.6152 - val_mean_absolute_error: 148.3111
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17574.7266 - mean_absolute_error: 128.4377 - val_loss: 17024.8672 - val_mean_absolute_error: 130.2763
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12896.6416 - mean_absolute_error: 109.1942 - val_loss: 13020.8174 - val_mean_absolute_error: 113.8765
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9942.6523 - mean_absolute_error: 94.4669 - val_loss: 9598.3350 - val_mean_absolute_error: 97.7004
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7096.8281 - mean_absolute_error: 78.1448 - val_loss: 6809.7373 - val_mean_absolute_error: 82.1996
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4754.1460 - mean_absolute_error: 61.5960 - val_loss: 4685.2368 - val_mean_absolute_error: 68.0608
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3296.4963 - mean_absolute_error: 48.4312 - val_loss: 3134.5554 - val_mean_absolute_error: 55.5120
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2389.9373 - mean_absolute_error: 39.1122 - val_loss: 2016.8997 - val_mean_absolute_error: 44.3143
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1788.7974 - mean_absolute_error: 34.0713 - val_loss: 1054.8719 - val_mean_absolute_error: 31.6538
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1277.6525 - mean_absolute_error: 30.1318 - val_loss: 639.2094 - val_mean_absolute_error: 24.2126
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 993.1788 - mean_absolute_error: 26.3506 - val_loss: 421.8404 - val_mean_absolute_error: 19.2062
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 975.8583 - mean_absolute_error: 26.1993 - val_loss: 310.4597 - val_mean_absolute_error: 16.0467
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 962.4940 - mean_absolute_error: 26.1774 - val_loss: 256.0616 - val_mean_absolute_error: 14.3690
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1032.4323 - mean_absolute_error: 27.1662 - val_loss: 230.3954 - val_mean_absolute_error: 13.5126
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1060.7236 - mean_absolute_error: 27.9230 - val_loss: 226.5824 - val_mean_absolute_error: 13.3802
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1030.7102 - mean_absolute_error: 27.5225 - val_loss: 230.3626 - val_mean_absolute_error: 13.5114
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 998.5946 - mean_absolute_error: 26.6877 - val_loss: 241.9904 - val_mean_absolute_error: 13.9067
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 959.6804 - mean_absolute_error: 25.9686 - val_loss: 254.0988 - val_mean_absolute_error: 14.3055
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1043.1577 - mean_absolute_error: 27.3262 - val_loss: 267.2535 - val_mean_absolute_error: 14.7254
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 935.4769 - mean_absolute_error: 25.4665 - val_loss: 282.6056 - val_mean_absolute_error: 15.1995
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 972.4288 - mean_absolute_error: 26.5229 - val_loss: 291.0946 - val_mean_absolute_error: 15.4549
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 989.4882 - mean_absolute_error: 26.3982 - val_loss: 281.4952 - val_mean_absolute_error: 15.1658
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1011.7547 - mean_absolute_error: 26.9651 - val_loss: 294.3367 - val_mean_absolute_error: 15.5512
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 939.4261 - mean_absolute_error: 25.5163 - val_loss: 283.3162 - val_mean_absolute_error: 15.2211
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 983.7927 - mean_absolute_error: 26.2779 - val_loss: 279.3762 - val_mean_absolute_error: 15.1012
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 963.9639 - mean_absolute_error: 26.2494 - val_loss: 279.4095 - val_mean_absolute_error: 15.1022
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 988.9971 - mean_absolute_error: 26.9435 - val_loss: 280.5726 - val_mean_absolute_error: 15.1377
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1029.9556 - mean_absolute_error: 27.1793 - val_loss: 281.0163 - val_mean_absolute_error: 15.1513
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 965.5911 - mean_absolute_error: 26.0210 - val_loss: 277.6557 - val_mean_absolute_error: 15.0485
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 928.7642 - mean_absolute_error: 25.5684 - val_loss: 270.6234 - val_mean_absolute_error: 14.8310
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1005.6445 - mean_absolute_error: 27.1482 - val_loss: 272.1840 - val_mean_absolute_error: 14.8807
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 955.6657 - mean_absolute_error: 25.5420 - val_loss: 456.5076 - val_mean_absolute_error: 20.1117
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 975.1443 - mean_absolute_error: 26.2712 - val_loss: 257.5628 - val_mean_absolute_error: 14.4356
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 978.3837 - mean_absolute_error: 26.6592 - val_loss: 244.2334 - val_mean_absolute_error: 14.0027
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 933.4888 - mean_absolute_error: 25.4795 - val_loss: 351.9473 - val_mean_absolute_error: 17.3481
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 969.5102 - mean_absolute_error: 26.3220 - val_loss: 259.8932 - val_mean_absolute_error: 14.5322
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 937.0404 - mean_absolute_error: 25.9746 - val_loss: 351.0864 - val_mean_absolute_error: 17.3566
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 949.1390 - mean_absolute_error: 26.3846 - val_loss: 266.6941 - val_mean_absolute_error: 14.7640
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 948.2409 - mean_absolute_error: 26.3338 - val_loss: 305.5844 - val_mean_absolute_error: 16.0180
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 860.3784 - mean_absolute_error: 24.7668 - val_loss: 275.2831 - val_mean_absolute_error: 15.0671
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 860.6442 - mean_absolute_error: 24.8985 - val_loss: 233.7295 - val_mean_absolute_error: 13.7383
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 796.6294 - mean_absolute_error: 23.8531 - val_loss: 335.4806 - val_mean_absolute_error: 17.0122
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 806.2219 - mean_absolute_error: 24.0647 - val_loss: 191.3483 - val_mean_absolute_error: 12.2564
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 724.9473 - mean_absolute_error: 22.2709 - val_loss: 348.0645 - val_mean_absolute_error: 17.4286
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 726.1747 - mean_absolute_error: 22.5441 - val_loss: 200.0186 - val_mean_absolute_error: 12.6369
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 687.1937 - mean_absolute_error: 21.8268 - val_loss: 246.0391 - val_mean_absolute_error: 14.2725
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 649.4061 - mean_absolute_error: 21.6219 - val_loss: 227.7881 - val_mean_absolute_error: 13.6763
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 627.8903 - mean_absolute_error: 21.2096 - val_loss: 197.7391 - val_mean_absolute_error: 12.6514
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 604.2037 - mean_absolute_error: 20.6805 - val_loss: 158.2970 - val_mean_absolute_error: 11.1276
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 497.5323 - mean_absolute_error: 18.6547 - val_loss: 286.6589 - val_mean_absolute_error: 15.8071
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 478.5233 - mean_absolute_error: 18.3125 - val_loss: 60.2071 - val_mean_absolute_error: 6.1763
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 431.1174 - mean_absolute_error: 17.3501 - val_loss: 61.7532 - val_mean_absolute_error: 6.2672
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 474.3672 - mean_absolute_error: 18.6933 - val_loss: 178.9056 - val_mean_absolute_error: 12.0509
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 341.4214 - mean_absolute_error: 15.3226 - val_loss: 153.5526 - val_mean_absolute_error: 11.0460
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 268.6715 - mean_absolute_error: 13.8573 - val_loss: 162.0293 - val_mean_absolute_error: 11.4024
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 259.3306 - mean_absolute_error: 12.7983 - val_loss: 63.6049 - val_mean_absolute_error: 6.4919
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 232.6453 - mean_absolute_error: 12.4080 - val_loss: 32.3111 - val_mean_absolute_error: 4.9050
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 212.9350 - mean_absolute_error: 12.1717 - val_loss: 43.8001 - val_mean_absolute_error: 5.5639
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 194.6700 - mean_absolute_error: 11.9089 - val_loss: 31.7156 - val_mean_absolute_error: 4.8563
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 152.8820 - mean_absolute_error: 10.2185 - val_loss: 30.6574 - val_mean_absolute_error: 4.8704
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 132.7993 - mean_absolute_error: 9.6869 - val_loss: 31.7214 - val_mean_absolute_error: 4.9796
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 96.3122 - mean_absolute_error: 7.8318 - val_loss: 30.0836 - val_mean_absolute_error: 4.8658
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 79.4179 - mean_absolute_error: 6.9803 - val_loss: 35.0675 - val_mean_absolute_error: 4.8668
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 61.3130 - mean_absolute_error: 6.1828 - val_loss: 30.1928 - val_mean_absolute_error: 4.8583
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 51.8655 - mean_absolute_error: 5.3175 - val_loss: 31.9684 - val_mean_absolute_error: 4.8408
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 47.8322 - mean_absolute_error: 5.1764 - val_loss: 30.4710 - val_mean_absolute_error: 4.8174
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 45.1006 - mean_absolute_error: 5.1502 - val_loss: 96.5407 - val_mean_absolute_error: 8.1892
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 64.6321 - mean_absolute_error: 7.1008 - val_loss: 95.2176 - val_mean_absolute_error: 8.1181
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 62.3995 - mean_absolute_error: 6.5344 - val_loss: 32.1964 - val_mean_absolute_error: 4.9117
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 65.8026 - mean_absolute_error: 6.5809 - val_loss: 39.4912 - val_mean_absolute_error: 5.4664
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 39.2541 - mean_absolute_error: 5.1820 - val_loss: 40.3036 - val_mean_absolute_error: 5.5200
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 39.1754 - mean_absolute_error: 5.1280 - val_loss: 32.6350 - val_mean_absolute_error: 4.9380
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 36.6209 - mean_absolute_error: 4.8886 - val_loss: 31.8913 - val_mean_absolute_error: 4.8324
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 30.4205 - mean_absolute_error: 4.2842 - val_loss: 52.3334 - val_mean_absolute_error: 5.6346
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 31.3444 - mean_absolute_error: 4.5476 - val_loss: 74.8203 - val_mean_absolute_error: 6.9419
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 31.6120 - mean_absolute_error: 4.6305 - val_loss: 61.9362 - val_mean_absolute_error: 6.1261
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.9742 - mean_absolute_error: 4.4236 - val_loss: 75.4584 - val_mean_absolute_error: 6.9841

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
loss, mae = model.evaluate(X_test, y_test)
print(f'Mean Absolute Error: {mae}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 89.3447 - mean_absolute_error: 7.9470
# Mean Absolute Error: 7.9470319747924805

# %%
# Generate predictions
y_pred = model.predict(X_test)

# Calculate Mean Squared Error (MSE)
mse = np.mean((y_test - y_pred)**2)
print(f'Mean Squared Error: {mse}')

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(y_test - y_pred))
print(f'Mean Absolute Error: {mae}')

# If you want to calculate R2 Score
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f'R2 Score: {r2}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Mean Squared Error: 163.42047119140625
# Root Mean Squared Error: 12.783601760864258
# Mean Absolute Error: 10.326831817626953
# R2 Score: -0.358892673010631

# %%
predicted = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
predicted_value = []
test = []
for i in predicted:
    predicted_value.append(np.argmax(i))
    
for i in y_test:
    test.append(np.argmax(i))

# %%
Lower values for MAE, MSE, and RMSE indicate better performance, while a higher R2 score indicates a better fit of the model to the data.
